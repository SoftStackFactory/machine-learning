# %% [markdown]
# #### Install Pandas Profiling Package

# %%
# !pip install -U pandas-profiling
# Out:
# Requirement already up-to-date: pandas-profiling in /usr/local/lib/python3.6/dist-packages (2.3.0)
# ...

# %%
import numpy as np
import pandas as pd
import pandas_profiling

# %% [markdown]
# ##### Mount Drive - **Google Colab Only Step**
#
# 1.   List item
# 2.   List item
#
#
# When using google colab inorder to access files on our google drive we need to mount the drive by running the below python cell, then clicking the link it generates and pasting the code in the cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change Directory To Access The Dependent Files - **Google Colab Only Step**

# %%
# %cd drive/Shared\ drives/Rubrik/Data\ Science/Fall\ 2019\ DS201-2/
# Out:
# /content/drive/Shared drives/Rubrik/Data Science/Fall 2019 DS201-2

# %% [markdown]
# ### Import Data
# Read in the real estate dataset using the following path and store it in a variable called `df`.
#
# #### Import the cleaned real estate dataset
# - Use pandas' `read_csv()` function
#
# #### Pandas' `read_csv()` parameters:
# - `filepath_or_buffer` (string): path of csv to import
#
# ```python
# filepath_or_buffer = './data/cleaned_and_feature_engineered_real_estate_.csv'
# ```

# %%
df = pd.read_csv(filepath_or_buffer = './data/cleaned_and_feature_engineered_real_estate.csv')

# %% [markdown]
# #### Run Profile Report on Data Frame

# %%
df.profile_report( style={'full_width':True,'theme': "flatly", 'primary_color': "#2c3e50"}, plot={'histogram': {'bins': 100}} )
# Out:
# Output hidden; open in https://colab.research.google.com to view.
